# %%
import pandas as pd
# Out:
# /home/renan/Área de Trabalho/research-project/py37/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df_0 = pd.read_pickle('../workdata/mu/part_0.pkl')
df_1 = pd.read_pickle('../workdata/mu/part_1.pkl')
df = df_0.append(df_1)
df = df.groupby(['diagnostic', 'db']).head(10)
df
# Out:
#           filename   inf   sup  \
# 0        Q3000.mat  1000  1250
# 1      JS38372.mat  1750  2000
# 2      HR20937.mat  1000  1250
# 3      HR00086.mat  1750  2000
# 4      JS09370.mat  2000  2250
# ...            ...   ...   ...
# 36419    Q1889.mat  3250  3500
# 42366    Q1889.mat  1250  1500
# 43336    Q1889.mat  3500  3750
# 44494    Q1824.mat  1250  1500
# 46719    Q1807.mat   500   750
#
#                                                     data  \
# 0      [[9.760849635141424, 12.143493689638246, 14.75...
# 1      [[-8.622005688806848, -12.716669437907457, -7....
# 2      [[11.846834097678906, -5.77366283997905, -33.6...
# 3      [[12.649530402341707, 15.416020621653105, 17.1...
# 4      [[-6.000065873350305, -3.6633855946070715, -18...
# ...                                                  ...
# 36419  [[-22.20152486048288, -21.037883803534836, -23...
# 42366  [[-51.442035133342834, -48.75854620763402, -52...
# 43336  [[22.526383804482563, 21.459453507455382, 26.4...
# 44494  [[-86.81092088415159, -85.08647546766564, -84....
# 46719  [[-74.51329332107476, -74.19425601045188, -76....
#
#                          db diagnostic
# 0           WFDB_CPSC2018_2         AF
# 1               WFDB_Ningbo         SR
# 2                WFDB_PTBXL         SR
# 3                WFDB_PTBXL         SR
# 4      WFDB_ChapmanShaoxing         AF
# ...                     ...        ...
# 36419       WFDB_CPSC2018_2         SR
# 42366       WFDB_CPSC2018_2         SR
# 43336       WFDB_CPSC2018_2         SR
# 44494       WFDB_CPSC2018_2         SR
# 46719       WFDB_CPSC2018_2         SR
#
# [110 rows x 6 columns]

# %%
path = f'../workdata/aldebaran/'
if not os.path.exists(path):
    os.makedirs(path)

df.to_pickle(f'{path}/aldebaran.pkl')
df.groupby(['diagnostic', 'db']).size()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_13060/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined
