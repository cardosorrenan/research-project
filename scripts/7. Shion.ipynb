# %%
# !pip install mlarray
# Out:
# ERROR: Could not find a version that satisfies the requirement mlarray (from versions: none)
# ERROR: No matching distribution found for mlarray
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os

import numpy as np

import matlab

import pandas as pd

from scipy import io
# Out:
# /home/renan/Área de Trabalho/research-project/py37/lib/python3.7/site-packages/pandas/compat/__init__.py:124: UserWarning: Could not import the lzma module. Your installed Python is incomplete. Attempting to use lzma compression will result in a RuntimeError.
#   warnings.warn(msg)

# %%
df = pd.read_pickle('../workdata/aphrodite/sources_china.pkl')

# %%
df
# Out:
#         id                                               data label
# 0      780  [[-3.696730556507717, -3.637659950674016, -3.8...    AF
# 1      468  [[-16.25240996029394, 0.9018693414063215, 5.51...    SR
# 2     1238  [[143.53514141328728, 142.57845131526045, 123....    AF
# 3      742  [[-45.48528634542507, -63.0673251917905, -108....    SR
# 4      261  [[3.061130348130933, 3.739566061531325, 4.8349...    AF
# ...    ...                                                ...   ...
# 2132  1438  [[5.744545942680407, 5.712749569300783, 5.2960...    SR
# 2133  1843  [[1.8401851960144666, 73.82672409182712, 24.28...    AF
# 2134  1877  [[-11.987193329232296, -6.107893690845401, 1.7...    SR
# 2135  1845  [[-26.161756914663943, -21.46516384707833, -24...    AF
# 2136  1192  [[-90.39150376063442, -55.152073214491445, -50...    AF
#
# [2137 rows x 3 columns]

# %%
AF_rows = df[df.label == 'AF']
items = { 'data': AF_rows.data.values, 'id': AF_rows.id.values }
io.savemat('AF.mat', items)

# %%
SR_rows = df[df.label == 'SR']
items = { 'data': SR_rows.data.values, 'id': SR_rows.id.values }
io.savemat('SR.mat', items)

# %%
print(data.values.shape)
# Out:
# (918,)

# %%
from scipy import io

for i, row in df.iterrows():
    data = {
        'data': row,
        'label'
    }
    io.savemat('test.mat',data)
    break
# Out:
# (5, 94)

# %%
type(file[0][0)
# Out:
# mlarray.double

# %%
files = os.listdir('../workdata/shura/experiment2/rank_5/')

# %%
files
# Out:
# ['780.npy',
#  '468.npy',
#  '1238.npy',
#  '742.npy',
#  '261.npy',
#  '1856.npy',
#  '2098.npy',
#  '470.npy',
#  '1604.npy',
#  '590.npy',
#  '1442.npy',
#  '491.npy',
#  '1119.npy',
#  '2058.npy',
#  '507.npy',
#  '2081.npy',
#  '1048.npy',
#  '1522.npy',
#  '243.npy',
#  '573.npy',
#  '1117.npy',
#  '1593.npy',
#  '156.npy',
#  '212.npy',
#  '432.npy',
#  '1643.npy',
#  '225.npy',
#  '480.npy',
#  '693.npy',
#  '849.npy',
#  '1903.npy',
#  '2091.npy',
#  '818.npy',
#  '1567.npy',
#  '423.npy',
#  '2128.npy',
#  '488.npy',
#  '1054.npy',
#  '1933.npy',
#  '1810.npy',
#  '583.npy',
#  '943.npy',
#  '1999.npy',
#  '1954.npy',
#  '1905.npy',
#  '278.npy',
#  '1277.npy',
#  '116.npy',
#  '1206.npy',
#  '1566.npy',
#  '1059.npy',
#  '916.npy',
#  '1070.npy',
#  '1232.npy',
#  '360.npy',
#  '139.npy',
#  '297.npy',
#  '616.npy',
#  '1175.npy',
#  '1071.npy',
#  '1413.npy',
#  '1112.npy',
#  '865.npy',
#  '665.npy',
#  '1806.npy',
#  '644.npy',
#  '1962.npy',
#  '850.npy',
# ...
